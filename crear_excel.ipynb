# %% [markdown]
# ### Practica 2 Bloque 4
# Lara Ocón Madrid - 202115710

# %%
# Para este practica vamos a crear un excel con un reporte ejecutivo de la pizzeria Maven Pizzas
# Para ello, empleamos la libreria openpyxl

# %%
import pandas as pd
import openpyxl

# %%
df_pizzas_semana = pd.read_csv('ficheros_csv/pizzas_semana.csv')
df_pizzas_semana.head()
# Out:
#                  0         1            2          3           4         5   \
# Unnamed: 0  bbq_ckn  cali_ckn  ckn_alfredo  ckn_pesto  southw_ckn  thai_ckn
# semana 0       29.0      12.5          2.5       10.5        19.0      25.0
# semana 1       58.0      65.0         49.0       28.5        38.5      64.0
# semana 2       61.5      55.0         15.5       27.0        68.5      58.5
# semana 3       73.5      83.0         22.0       25.0        36.5      65.5
#
#                   6            7         8            9   ...            22  \
# Unnamed: 0  big_meat  classic_dlx  hawaiian  ital_cpcllo  ...  spinach_supr
# semana 0        12.0         23.0      18.0         17.0  ...          13.0
# semana 1        34.0         63.5      63.5         33.5  ...          27.0
# semana 2        22.0         46.0      42.0         30.5  ...          26.0
# semana 3        35.0         49.0      60.0         34.5  ...          18.0
#
#                      23           24            25           26            27  \
# Unnamed: 0  five_cheese  four_cheese  green_garden  ital_veggie  mediterraneo
# semana 0           18.0         14.5           6.5          7.5           7.0
# semana 1           60.0         64.0          24.0         27.0          19.5
# semana 2           54.0         47.5          13.0         22.0          19.5
# semana 3           58.0         68.5          20.0         36.5          25.5
#
#                   28          29           30          31
# Unnamed: 0  mexicana  spin_pesto  spinach_fet  veggie_veg
# semana 0        19.5         6.0          8.0        11.5
# semana 1        37.0        28.0         43.0        38.5
# semana 2        47.0        29.5         45.5        45.5
# semana 3        34.5        20.0         37.0        42.0
#
# [5 rows x 32 columns]

# %%
# vamos a crear una tabla pivote que muestre la resta de ingredientes necesitados y predichos
df_concat = pd.concat([df_ingredientes_semana, df_predicciones], axis=0)
df_concat = df_concat.iloc[-1] - df_concat.iloc[:-1]
tabla_diferencia = df_concat.pivot_table(indes=df_concat.index, columns=df_ingredientes_semana.values, aggfunc='sum')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/computation/expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/roperator.py:13, in rsub(left, right)
#      12 def rsub(left, right):
# ---> 13     return right - left
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/adquision_datos/Bloque4/Practica2_Bloque4/crear_excel.ipynb Celda 7 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/adquision_datos/Bloque4/Practica2_Bloque4/crear_excel.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # vamos a crear una tabla pivote que muestre la resta de ingredientes necesitados y predichos
#       <a href='vscode-notebook-cell:/Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/adquision_datos/Bloque4/Practica2_Bloque4/crear_excel.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> df_concat = pd.concat([df_ingredientes_semana, df_predicciones], axis=0)
# ----> <a href='vscode-notebook-cell:/Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/adquision_datos/Bloque4/Practica2_Bloque4/crear_excel.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> df_concat = df_concat.iloc[-1] - df_concat.iloc[:-1]
#       <a href='vscode-notebook-cell:/Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/adquision_datos/Bloque4/Practica2_Bloque4/crear_excel.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> tabla_diferencia = df_concat.pivot_table(indes=df_concat.index, columns=df_ingredientes_semana.values, aggfunc='sum')
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:112, in OpsMixin.__rsub__(self, other)
#     110 @unpack_zerodim_and_defer("__rsub__")
#     111 def __rsub__(self, other):
# --> 112     return self._arith_method(other, roperator.rsub)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:6940, in DataFrame._arith_method(self, other, op)
#    6936 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6938 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
# -> 6940 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6941 return self._construct_result(new_data)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:6979, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    6973     # TODO: The previous assertion `assert right._indexed_same(self)`
#    6974     #  fails in cases with empty columns reached via
#    6975     #  _frame_arith_method_with_reindex
#    6976
#    6977     # TODO operate_blockwise expects a manager of the same type
#    6978     with np.errstate(all="ignore"):
# -> 6979         bm = self._mgr.operate_blockwise(
#    6980             # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    6981             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    6982             # "ArrayManager"
#    6983             # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    6984             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    6985             # "BlockManager"
#    6986             right._mgr,  # type: ignore[arg-type]
#    6987             array_op,
#    6988         )
#    6989     return self._constructor(bm)
#    6991 elif isinstance(right, Series) and axis == 1:
#    6992     # axis=1 means we want to operate row-by-row
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py:1409, in BlockManager.operate_blockwise(self, other, array_op)
#    1405 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1406     """
#    1407     Apply array_op blockwise with another (aligned) BlockManager.
#    1408     """
# -> 1409     return operate_blockwise(self, other, array_op)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/ops.py:63, in operate_blockwise(left, right, array_op)
#      61 res_blks: list[Block] = []
#      62 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 63     res_values = array_op(lvals, rvals)
#      64     if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      65         res_values = res_values.reshape(1, -1)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:222, in arithmetic_op(left, right, op)
#     217 else:
#     218     # TODO we should handle EAs consistently and move this check before the if/else
#     219     # (https://github.com/pandas-dev/pandas/issues/41165)
#     220     _bool_arith_check(op, left, right)
# --> 222     res_values = _na_arithmetic_op(left, right, op)
#     224 return res_values
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:170, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 except TypeError:
#     165     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     166         # For object dtype, fallback to a masked operation (only operating
#     167         #  on the non-missing values)
#     168         # Don't do this for comparisons, as that will handle complex numbers
#     169         #  incorrectly, see GH#32047
# --> 170         result = _masked_arith_op(left, right, op)
#     171     else:
#     172         raise
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:108, in _masked_arith_op(x, y, op)
#     106     # See GH#5284, GH#5035, GH#19448 for historical reference
#     107     if mask.any():
# --> 108         result[mask] = op(xrav[mask], yrav[mask])
#     110 else:
#     111     if not is_scalar(y):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/roperator.py:13, in rsub(left, right)
#      12 def rsub(left, right):
# ---> 13     return right - left
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
